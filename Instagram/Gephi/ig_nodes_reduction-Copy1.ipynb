# %%
import pandas as pd
df = pd.read_csv('Output.csv')
df
# Out:
#                       followers        foodies
# 0                kralice_ime_ne      8days_eat
# 1                   auroracampp      8days_eat
# 2                 er.nawati8113      8days_eat
# 3                        mkkb98      8days_eat
# 4                   daisydan100      8days_eat
# 5                  seahtaurus99      8days_eat
# 6                   myhappifood      8days_eat
# 7      palace_korean_restaurant      8days_eat
# 8                       ccewooi      8days_eat
# 9                   sharon_zzzy      8days_eat
# 10                   bakeoozysg      8days_eat
# 11                   kolakola72      8days_eat
# 12         flower_cosmetic_shop      8days_eat
# 13                   _thewarung      8days_eat
# 14                   sylvviaa18      8days_eat
# 15              yingstagram0107      8days_eat
# 16                     limsy110      8days_eat
# 17                 aliescobar02      8days_eat
# 18                    jacchua12      8days_eat
# 19               euniceyapjiali      8days_eat
# 20                   saymio1989      8days_eat
# 21                   kim.ogri27      8days_eat
# 22             ramesh.dontaraju      8days_eat
# 23                chrisliwei199      8days_eat
# 24                    audreycmh      8days_eat
# 25                  hdominiqueg      8days_eat
# 26                 tts_eurocars      8days_eat
# 27                  andrew.chia      8days_eat
# 28                    irenehoon      8days_eat
# 29          chilipadilovepastry      8days_eat
# ...                         ...            ...
# 86293                  kairihui  thesilverchef
# 86294           peppermint.pout  thesilverchef
# 86295                  juniakok  thesilverchef
# 86296                 dharshi04  thesilverchef
# 86297              marigoldtown  thesilverchef
# 86298                  supimted  thesilverchef
# 86299               daphneee_wg  thesilverchef
# 86300              angleonghuat  thesilverchef
# 86301                 its___eve  thesilverchef
# 86302               simran.teli  thesilverchef
# 86303                 nanette_9  thesilverchef
# 86304                foodalbum1  thesilverchef
# 86305           foodiesappetite  thesilverchef
# 86306                   landylw  thesilverchef
# 86307                  ndt_uyen  thesilverchef
# 86308            stephhhalianto  thesilverchef
# 86309                 alwyn_pek  thesilverchef
# 86310                posttoling  thesilverchef
# 86311               tayyongsing  thesilverchef
# 86312                store.eosg  thesilverchef
# 86313                 ling_0909  thesilverchef
# 86314               cheryljiang  thesilverchef
# 86315                  yourkama  thesilverchef
# 86316                 lisa_gwee  thesilverchef
# 86317      ricebowlandchopstick  thesilverchef
# 86318                  hanyhnee  thesilverchef
# 86319      roselimariade.franca  thesilverchef
# 86320                 veron2970  thesilverchef
# 86321                c_y_cheong  thesilverchef
# 86322                  mouseyan  thesilverchef
#
# [86323 rows x 2 columns]

# %%
count = df['followers'].value_counts()
count
# Out:
# team_catering                  12
# jessicach03                    12
# saymio1989                     12
# yammycakesg                    11
# ihustleatravelust              11
# fooddiekuu                     11
# tginasilemak                   11
# wongfulleats                   11
# majesticbayrestaurantsg        11
# honeynyou_sg                   11
# kongbakbao.sg                  11
# skinniefoodies                 11
# good_heart_good_eats_          11
# facemaskexpress.sg             11
# laurel_beautifulvenues_food    11
# fooding_good_life              11
# iamkeffie                      11
# wfhkitchen.co                  10
# fullstop.sin                   10
# sourspicykimchi                10
# seatobag                       10
# soulsugarbakes                 10
# onetastymoment                 10
# sweetnessthatlingers           10
# a.counting.cook                10
# dizzydumplings                 10
# billyrusso786                  10
# jasonpenangcuisine             10
# gogogluttons                   10
# brunchunnie                    10
#                                ..
# annisashrfna                    1
# _seiraaaaa_                     1
# hunnwai                         1
# seng_says                       1
# gyinjie                         1
# shinsyoji                       1
# reginalimcl                     1
# hanganlinh                      1
# yuniatns                        1
# tbk.magic                       1
# splashske                       1
# sebaslim_                       1
# bernardho                       1
# bearysg                         1
# amandaarachell                  1
# _funplayer3220_                 1
# _sfng_                          1
# lorra_drizzle                   1
# wesley_wee                      1
# darya_spam_account              1
# vivien_tan                      1
# jasminetangsh                   1
# orphmedia                       1
# mamarourwindowslive.com4697     1
# beatriciainspirit               1
# judy.lai.7505                   1
# s_charm                         1
# sirine.djapa                    1
# ailee_audrey                    1
# yzkaieats                       1
# Name: followers, Length: 63660, dtype: int64

# %%
new = df[df['followers'].isin(count[count==2].index)]
new
# Out:
#                             followers        foodies
# 9                         sharon_zzzy      8days_eat
# 18                          jacchua12      8days_eat
# 19                     euniceyapjiali      8days_eat
# 22                   ramesh.dontaraju      8days_eat
# 27                        andrew.chia      8days_eat
# 32                         bettyyyz01      8days_eat
# 35                             ronwch      8days_eat
# 41                            j_chiau      8days_eat
# 42                     angiethechoice      8days_eat
# 51                         nanimona61      8days_eat
# 56                          leonaheng      8days_eat
# 70                      abiteofjoy.sg      8days_eat
# 73                    simplefoodtings      8days_eat
# 82                        geoffreylip      8days_eat
# 86                         jess.88123      8days_eat
# 87                   meicandrasynatra      8days_eat
# 89                      sdicapriology      8days_eat
# 95                             _snxt_      8days_eat
# 102                  beecreativequote      8days_eat
# 107                    bakerhouse.bmt      8days_eat
# 116                         hidefansg      8days_eat
# 120         evofina_effective_academy      8days_eat
# 138                     chrispchiggen      8days_eat
# 147                       jialee_krys      8days_eat
# 150                          gancindy      8days_eat
# 153                      yennibanenny      8days_eat
# 157                          lcl30mdr      8days_eat
# 166                   shirokumaonroad      8days_eat
# 169                           rozi_38      8days_eat
# 180                      monica.goh.9      8days_eat
# ...                               ...            ...
# 86081                        nitnotes  thesilverchef
# 86082        redvelvetcheesefrostings  thesilverchef
# 86090         cyn_not_so_secret_diary  thesilverchef
# 86091                     dinnnerdiet  thesilverchef
# 86092                     anjelinateh  thesilverchef
# 86096                        decerica  thesilverchef
# 86104                        pearkies  thesilverchef
# 86106                  cookingmama.co  thesilverchef
# 86115                          r2sara  thesilverchef
# 86120                       lynn_guan  thesilverchef
# 86127                    selena180645  thesilverchef
# 86133                   old.macstuffy  thesilverchef
# 86166                      hengjuliet  thesilverchef
# 86169  ________________________n_h___  thesilverchef
# 86183                thislittleoyster  thesilverchef
# 86185                         xfshoko  thesilverchef
# 86190                         ling_go  thesilverchef
# 86193                         misskpo  thesilverchef
# 86197                         cordyqh  thesilverchef
# 86207                   cocinadetania  thesilverchef
# 86213                          kywrie  thesilverchef
# 86216                        dorcling  thesilverchef
# 86234                       wynlyntan  thesilverchef
# 86239                   domesticassie  thesilverchef
# 86241                 donutexpedition  thesilverchef
# 86263                         ame6810  thesilverchef
# 86278                  paristaipei128  thesilverchef
# 86299                     daphneee_wg  thesilverchef
# 86311                     tayyongsing  thesilverchef
# 86319            roselimariade.franca  thesilverchef
#
# [12632 rows x 2 columns]

# %%
new.to_csv('3295_rows.csv')

# %%
count = new['followers'].value_counts()
count
# Out:
# saymio1989                     12
# jessicach03                    12
# team_catering                  12
# fooddiekuu                     11
# iamkeffie                      11
# facemaskexpress.sg             11
# good_heart_good_eats_          11
# majesticbayrestaurantsg        11
# wongfulleats                   11
# honeynyou_sg                   11
# ihustleatravelust              11
# kongbakbao.sg                  11
# tginasilemak                   11
# fooding_good_life              11
# yammycakesg                    11
# laurel_beautifulvenues_food    11
# skinniefoodies                 11
# wcl_mysg                       10
# soulsugarbakes                 10
# billyrusso786                  10
# menusandvenues.sg              10
# ay.den5510                     10
# tts_eurocars                   10
# sweetnessthatlingers           10
# ms_syltong                     10
# a.counting.cook                10
# onetastymoment                 10
# fnbsays.sg                     10
# danielsmellysa                 10
# percivalbuensalida             10
#                                ..
# deenkooks                       7
# poklol.tv                       7
# whimsical.woodlands             7
# viewerstravel                   7
# instongram20                    7
# xiexieni.sg                     7
# food_monsterz                   7
# jwalangrg                       7
# sansan_cooks                    7
# michikoraerae                   7
# backdoor_alley                  7
# alicechienll                    7
# malzvlogs                       7
# lepetitcroissantasia            7
# quikerly.sg                     7
# oimakanalr                      7
# sylovesfood                     7
# sharonmah6                      7
# yamadad.hk                      7
# snackit.sg                      7
# johnnywong5566                  7
# _2ir.j                          7
# dirtybunsg                      7
# jsapphirenini                   7
# sgkofuku                        7
# bodegas_solis                   7
# billy_shabani                   7
# xtrasgg                         7
# fiery.141                       7
# jamie_old_item_collector        7
# Name: followers, Length: 414, dtype: int64
