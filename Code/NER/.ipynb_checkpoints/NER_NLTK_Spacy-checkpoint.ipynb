# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import nltk
# nltk.download('maxent_ne_chunker')
# nltk.download('words')
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk

# %%
sentence = 'Katong’s famous Hokkien mee and fried mee sua hawker stall Yong Huat at Alibabar kopitiam is closing permanently. Read more via link in our profile (click on the URL that starts with ‘linkinprofile’ below the 8 Days logo). 📷: Kelvin Chia bit.ly/2BPA4DS'

# %%
ne_tree = ne_chunk(pos_tag(word_tokenize(sentence)))

# %%
print(ne_tree)
# Out:
# (S
#   (GPE Katong/NNP)
#   ’/NNP
#   s/VBP
#   famous/JJ
#   Hokkien/NNP
#   mee/NN
#   and/CC
#   fried/VBD
#   mee/NNS
#   sua/JJ
#   hawker/NN
#   stall/NN
#   (PERSON Yong/NNP Huat/NNP)
#   at/IN
#   (ORGANIZATION Alibabar/NNP)
#   kopitiam/NN
#   is/VBZ
#   closing/VBG
#   permanently/RB
#   ./.
#   Read/VB
#   more/JJR
#   via/IN
#   link/NN
#   in/IN
#   our/PRP$
#   profile/NN
#   (/(
#   click/NN
#   on/IN
#   the/DT
#   (ORGANIZATION URL/NNP)
#   that/WDT
#   starts/VBZ
#   with/IN
#   ‘/NNP
#   linkinprofile/NN
#   ’/NN
#   below/IN
#   the/DT
#   8/CD
#   Days/NNP
#   logo/NN
#   )/)
#   ./.
#   📷/NN
#   :/:
#   (PERSON Kelvin/NNP Chia/NNP)
#   bit.ly/2BPA4DS/NN)

# %%
ex = sentence

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(ex)
sent
# Out:
# [('Katong', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBP'),
#  ('famous', 'JJ'),
#  ('Hokkien', 'NNP'),
#  ('mee', 'NN'),
#  ('and', 'CC'),
#  ('fried', 'VBD'),
#  ('mee', 'NNS'),
#  ('sua', 'JJ'),
#  ('hawker', 'NN'),
#  ('stall', 'NN'),
#  ('Yong', 'NNP'),
#  ('Huat', 'NNP'),
#  ('at', 'IN'),
#  ('Alibabar', 'NNP'),
#  ('kopitiam', 'NN'),
#  ('is', 'VBZ'),
#  ('closing', 'VBG'),
#  ('permanently', 'RB'),
#  ('.', '.'),
#  ('Read', 'VB'),
#  ('more', 'JJR'),
#  ('via', 'IN'),
#  ('link', 'NN'),
#  ('in', 'IN'),
#  ('our', 'PRP$'),
#  ('profile', 'NN'),
#  ('(', '('),
#  ('click', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('URL', 'NNP'),
#  ('that', 'WDT'),
#  ('starts', 'VBZ'),
#  ('with', 'IN'),
#  ('‘', 'NNP'),
#  ('linkinprofile', 'NN'),
#  ('’', 'NN'),
#  ('below', 'IN'),
#  ('the', 'DT'),
#  ('8', 'CD'),
#  ('Days', 'NNP'),
#  ('logo', 'NN'),
#  (')', ')'),
#  ('.', '.'),
#  ('📷', 'NN'),
#  (':', ':'),
#  ('Kelvin', 'NNP'),
#  ('Chia', 'NNP'),
#  ('bit.ly/2BPA4DS', 'NN')]

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'

# %%
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   Katong/NNP
#   ’/NNP
#   s/VBP
#   famous/JJ
#   Hokkien/NNP
#   (NP mee/NN)
#   and/CC
#   fried/VBD
#   mee/NNS
#   (NP sua/JJ hawker/NN)
#   (NP stall/NN)
#   Yong/NNP
#   Huat/NNP
#   at/IN
#   Alibabar/NNP
#   (NP kopitiam/NN)
#   is/VBZ
#   closing/VBG
#   permanently/RB
#   ./.
#   Read/VB
#   more/JJR
#   via/IN
#   (NP link/NN)
#   in/IN
#   our/PRP$
#   (NP profile/NN)
#   (/(
#   (NP click/NN)
#   on/IN
#   the/DT
#   URL/NNP
#   that/WDT
#   starts/VBZ
#   with/IN
#   ‘/NNP
#   (NP linkinprofile/NN)
#   (NP ’/NN)
#   below/IN
#   the/DT
#   8/CD
#   Days/NNP
#   (NP logo/NN)
#   )/)
#   ./.
#   (NP 📷/NN)
#   :/:
#   Kelvin/NNP
#   Chia/NNP
#   (NP bit.ly/2BPA4DS/NN))

# %%
NPChunker = nltk.RegexpParser(pattern) 
result = NPChunker.parse(sent)
result.draw()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-10-ef9db3d1c363> in <module>
#       1 NPChunker = nltk.RegexpParser(pattern)
#       2 result = NPChunker.parse(sent)
# ----> 3 result.draw()
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\tree.py in draw(self)
#     748         from nltk.draw.tree import draw_trees
#     749
# --> 750         draw_trees(self)
#     751
#     752     def pretty_print(self, sentence=None, highlight=(), stream=None, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\draw\tree.py in draw_trees(*trees)
#    1006     :rtype: None
#    1007     """
# -> 1008     TreeView(*trees).mainloop()
#    1009     return
#    1010
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\draw\tree.py in __init__(self, *trees)
#     885                 line_color="#004040",
#     886                 draggable=1,
# ...

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint

iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('Katong', 'NNP', 'O'),
#  ('’', 'NNP', 'O'),
#  ('s', 'VBP', 'O'),
#  ('famous', 'JJ', 'O'),
#  ('Hokkien', 'NNP', 'O'),
#  ('mee', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('fried', 'VBD', 'O'),
#  ('mee', 'NNS', 'O'),
#  ('sua', 'JJ', 'B-NP'),
#  ('hawker', 'NN', 'I-NP'),
#  ('stall', 'NN', 'B-NP'),
#  ('Yong', 'NNP', 'O'),
#  ('Huat', 'NNP', 'O'),
#  ('at', 'IN', 'O'),
#  ('Alibabar', 'NNP', 'O'),
#  ('kopitiam', 'NN', 'B-NP'),
#  ('is', 'VBZ', 'O'),
#  ('closing', 'VBG', 'O'),
#  ('permanently', 'RB', 'O'),
#  ('.', '.', 'O'),
#  ('Read', 'VB', 'O'),
#  ('more', 'JJR', 'O'),
#  ('via', 'IN', 'O'),
#  ('link', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('our', 'PRP$', 'O'),
#  ('profile', 'NN', 'B-NP'),
#  ('(', '(', 'O'),
#  ('click', 'NN', 'B-NP'),
#  ('on', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('URL', 'NNP', 'O'),
#  ('that', 'WDT', 'O'),
#  ('starts', 'VBZ', 'O'),
#  ('with', 'IN', 'O'),
#  ('‘', 'NNP', 'O'),
#  ('linkinprofile', 'NN', 'B-NP'),
#  ('’', 'NN', 'B-NP'),
# ...

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc = nlp(sentence)
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('Katong', 'ORG'),
#  ('Hokkien', 'ORG'),
#  ('Yong Huat', 'ORG'),
#  ('Alibabar', 'ORG'),
#  ('the 8 Days', 'DATE'),
#  ('Kelvin Chia', 'PERSON')]

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(European, 'B', 'NORP'),
#  (authorities, 'O', ''),
#  (fined, 'O', ''),
#  (Google, 'B', 'ORG'),
#  (a, 'O', ''),
#  (record, 'O', ''),
#  ($, 'B', 'MONEY'),
#  (5.1, 'I', 'MONEY'),
#  (billion, 'I', 'MONEY'),
#  (on, 'O', ''),
#  (Wednesday, 'B', 'DATE'),
#  (for, 'O', ''),
#  (abusing, 'O', ''),
#  (its, 'O', ''),
#  (power, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (mobile, 'O', ''),
#  (phone, 'O', ''),
#  (market, 'O', ''),
#  (and, 'O', ''),
#  (ordered, 'O', ''),
#  (the, 'O', ''),
#  (company, 'O', ''),
#  (to, 'O', ''),
#  (alter, 'O', ''),
#  (its, 'O', ''),
#  (practices, 'O', '')]

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %%
ny_bb = url_to_string('https://www.nytimes.com/2018/08/13/us/politics/peter-strzok-fired-fbi.html?hp&action=click&pgtype=Homepage&clickSource=story-heading&module=first-column-region&region=top-news&WT.nav=top-news')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 188

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'CARDINAL': 5,
#          'DATE': 29,
#          'EVENT': 1,
#          'GPE': 35,
#          'LOC': 1,
#          'NORP': 5,
#          'ORDINAL': 1,
#          'ORG': 26,
#          'PERSON': 84,
#          'WORK_OF_ART': 1})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('Strzok', 32), ('F.B.I.', 17), ('Trump', 10)]

# %%
sentences = [x for x in article.sents]
print(sentences[20])
# Out:
# Firing Mr. Strzok, however, removes a favorite target of Mr. Trump from the ranks of the F.B.I. and gives Mr. Bowdich and the F.B.I. director, Christopher A. Wray, a chance to move beyond the president’s ire.

# %%
displacy.render(nlp(str(sentences[20])), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5">Firing Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , however, removes a favorite target of Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  from the ranks of the
# ...

# %%
displacy.render(nlp(str(sentences[20])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="4490" height="617.0" style="max-width: none; height: 617.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Firing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Mr.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Strzok,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# ...

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[20])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Firing', 'VERB', 'fire'),
#  ('Mr.', 'PROPN', 'mr.'),
#  ('Strzok', 'PROPN', 'strzok'),
#  ('removes', 'VERB', 'remove'),
#  ('favorite', 'ADJ', 'favorite'),
#  ('target', 'NOUN', 'target'),
#  ('Mr.', 'PROPN', 'mr.'),
#  ('Trump', 'PROPN', 'trump'),
#  ('ranks', 'NOUN', 'rank'),
#  ('F.B.I.', 'PROPN', 'f.b.i.'),
#  ('gives', 'VERB', 'give'),
#  ('Mr.', 'PROPN', 'mr.'),
#  ('Bowdich', 'PROPN', 'bowdich'),
#  ('F.B.I.', 'PROPN', 'f.b.i.'),
#  ('director', 'NOUN', 'director'),
#  ('Christopher', 'PROPN', 'christopher'),
#  ('A.', 'PROPN', 'a.'),
#  ('Wray', 'PROPN', 'wray'),
#  ('chance', 'NOUN', 'chance'),
#  ('president', 'NOUN', 'president'),
#  ('’s', 'PART', '’s'),
#  ('ire', 'NOUN', 'ire')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[20])).ents])
# Out:
# {'Bowdich': 'PERSON',
#  'Christopher A. Wray': 'PERSON',
#  'F.B.I.': 'GPE',
#  'Strzok': 'PERSON',
#  'Trump': 'PERSON'}

# %%
print([(x, x.ent_iob_, x.ent_type_) for x in sentences[20]])
# Out:
# [(Firing, 'O', ''), (Mr., 'O', ''), (Strzok, 'B', 'PERSON'), (,, 'O', ''), (however, 'O', ''), (,, 'O', ''), (removes, 'O', ''), (a, 'O', ''), (favorite, 'O', ''), (target, 'O', ''), (of, 'O', ''), (Mr., 'O', ''), (Trump, 'B', 'PERSON'), (from, 'O', ''), (the, 'O', ''), (ranks, 'O', ''), (of, 'O', ''), (the, 'O', ''), (F.B.I., 'B', 'GPE'), (and, 'O', ''), (gives, 'O', ''), (Mr., 'O', ''), (Bowdich, 'B', 'PERSON'), (and, 'O', ''), (the, 'O', ''), (F.B.I., 'B', 'GPE'), (director, 'O', ''), (,, 'O', ''), (Christopher, 'B', 'PERSON'), (A., 'I', 'PERSON'), (Wray, 'I', 'PERSON'), (,, 'O', ''), (a, 'O', ''), (chance, 'O', ''), (to, 'O', ''), (move, 'O', ''), (beyond, 'O', ''), (the, 'O', ''), (president, 'O', ''), (’s, 'O', ''), (ire, 'O', ''), (., 'O', '')]

# %%
displacy.render(article, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5">                                           F.B.I. Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Who Criticized Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in Texts, Is
# ...
